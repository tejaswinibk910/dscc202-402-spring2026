# %%
"""
To run this pipeline:

1. Set up Unity Catalog infrastructure:
   CREATE CATALOG IF NOT EXISTS main;
   CREATE SCHEMA IF NOT EXISTS main.default;
   CREATE VOLUME IF NOT EXISTS main.default.landing;
   CREATE VOLUME IF NOT EXISTS main.default.checkpoints;

2. Upload data:
   - customers.csv → /Volumes/main/default/landing/customers.csv
   - orders JSON → s3://your-bucket/orders/

3. Configure S3 access in Databricks:
   - Set up AWS credentials or instance profiles
   - Verify S3 bucket permissions

4. Run pipeline:
   spark-pipelines run --pipeline declarative_pipeline_orders.py

5. Monitor tables:
   SELECT COUNT(*) FROM customers;
   SELECT COUNT(*) FROM raw_orders;
   SELECT * FROM fact_orders LIMIT 10;

6. Test streaming:
   - Upload new JSON files to S3
   - Watch raw_orders and fact_orders auto-update
"""

# %%
# %sql
   CREATE CATALOG IF NOT EXISTS main;
   CREATE SCHEMA IF NOT EXISTS main.default;
   CREATE VOLUME IF NOT EXISTS main.default.landing;
   CREATE VOLUME IF NOT EXISTS main.default.checkpoints;
